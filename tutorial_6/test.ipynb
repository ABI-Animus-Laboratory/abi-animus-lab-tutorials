# %% [markdown]
# # Tutorial Alireza

# %%
import sys
print(sys.version)
# Out:
# 3.9.18 | packaged by conda-forge | (main, Dec 23 2023, 16:33:10)
# [GCC 12.3.0]

# %%
import pyvista
print(pyvista.__version__)
# Out:
# 0.43.4

# %%
# %env VTK_INCLUDE_DIRS=/opt/vita/vita_build/include/vtk-8.1
# %env VITA_INCLUDE_DIRS=/opt/vita/include/vita_source 
# %env VTK_LIBRARY_DIRS=/opt/vita/vita_build/lib 
# %env VITA_LIBRARY_DIRS=/opt/vita/lib
# Out:
# env: VTK_INCLUDE_DIRS=/opt/vita/vita_build/include/vtk-8.1
# env: VITA_INCLUDE_DIRS=/opt/vita/include/vita_source
# env: VTK_LIBRARY_DIRS=/opt/vita/vita_build/lib
# env: VITA_LIBRARY_DIRS=/opt/vita/lib

# %%
# !echo $VTK_INCLUDE_DIRS
# Out:
# /opt/vita/vita_build/include/vtk-8.1

# %%
# !cd /tutorials/tutorial_Alireza/example_1 && make -f Makefile clean && make -f Makefile
# Out:
# CMake Error: The source directory "/home" does not appear to contain CMakeLists.txt.
# Specify --help for usage, or press the help button on the CMake GUI.
# make: *** [Makefile:176: cmake_check_build_system] Error 1

# %%
# !cd /tutorials/tutorial_5/requirements_cpp/make_and_run_scripts && example_1
# Out:
# /usr/bin/sh: 1: example_1: not found

# %%
# !cd example_1 && make
# Out:
# CMake Error at CMakeLists.txt:16 (find_package):
#   By not providing "FindVTK.cmake" in CMAKE_MODULE_PATH this project has
#   asked CMake to find a package configuration file provided by "VTK", but
#   CMake did not find one.
#
#   Could not find a package configuration file provided by "VTK" with any of
#   the following names:
#
#     VTKConfig.cmake
#     vtk-config.cmake
#
#   Add the installation prefix of "VTK" to CMAKE_PREFIX_PATH or set "VTK_DIR"
#   to a directory containing one of the above files.  If "VTK" provides a
#   separate development package or SDK, be sure it has been installed.
#
#
# -- Configuring incomplete, errors occurred!
# make: *** [Makefile:179: cmake_check_build_system] Error 1

# %%
# !cd example_1 && ./example_1
# Out:
# ./example_1: error while loading shared libraries: libvtkIOLegacy-8.1.so.1: cannot open shared object file: No such file or directory

# %%
# 1. Move into the main project folder
# %cd ./MicrovascularModelling

# 2. Run the script (pointing to it inside the 'scripts' folder)
# %run scripts/base_lab_example.py
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /tutorials/tutorial_Alireza/MicrovascularModelling
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/numpy/core/__init__.py:24
#      23 try:
# ---> 24     from . import multiarray
#      25 except ImportError as exc:
#
# File /usr/lib/python3/dist-packages/numpy/core/multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File /usr/lib/python3/dist-packages/numpy/core/overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy.core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
# ...
