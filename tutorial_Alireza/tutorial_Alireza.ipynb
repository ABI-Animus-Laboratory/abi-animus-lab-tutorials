# %% [markdown]
# # Tutorial Alireza

# %%
import sys
print(sys.version)
# Out:
# 3.9.18 | packaged by conda-forge | (main, Dec 23 2023, 16:33:10)
# [GCC 12.3.0]

# %%
import pyvista
print(pyvista.__version__)
# Out:
# 0.43.4

# %%
# !cd example_1 && make
# Out:
# [ 50%] Building CXX object CMakeFiles/example_1.dir/example_1.cpp.o
# [100%] Linking CXX executable example_1
# [100%] Built target example_1

# %%
# !cd example_1 && ./example_1
# Out:
# Testing inside domain condition for 10000 points
# Trying segment #1 at terminal point (-0.90396, -0.566322, 0) with the 1 closest neighbors (dLim = 1).
# Added with a cost of 0.0065006
# Trying segment #2 at terminal point (0.800954, -0.687811, 0) with the 3 closest neighbors (dLim = 0.707107).
# Added with a cost of 0.000783083
# Trying segment #3 at terminal point (-0.817301, 0.53884, 0) with the 5 closest neighbors (dLim = 0.57735).
# Added with a cost of 0.00208727
# Trying segment #4 at terminal point (0.145403, -0.992351, 0) with the 7 closest neighbors (dLim = 0.5).
# Added with a cost of 0.000957513
# Trying segment #5 at terminal point (-0.843408, 0.0305277, 0) with the 9 closest neighbors (dLim = 0.447214).
# Added with a cost of 0.00081233
# Trying segment #6 at terminal point (-0.299329, -0.649925, 0) with the 11 closest neighbors (dLim = 0.408248).
# Added with a cost of 0.00015053
# ...

# %%
# 1. Move into the main project folder
# %cd ./MicrovascularModelling

# 2. Run the script (pointing to it inside the 'scripts' folder)
# %run scripts/base_lab_example.py
# Out:
# /opt/conda/envs/femSolver/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /tutorials/tutorial_Alireza/MicrovascularModelling
# 2026-02-04|13:50:08 - {'test_name': 'Test_x_1.6326530612244898_Steepness_6.0', 'x_position': 1.6326530612244898, 'steepness_value': 6.0}
# 2026-02-04|13:50:08 - outputs/base_lab_example/ratio_1.4/test_metrics/case_165
# 2026-02-04|13:50:08 - Output Path is vessel_test
# 2026-02-04|13:50:10 - Inlet Pressure set to 3986.268 Pa.
# 2026-02-04|13:50:10 -
#         Tree Information:
#           Number of Nodes: 249
#           Number of Segments: 248
#           Number of Junctions: 3
#           Tree Age: 0
#
# 2026-02-04|13:50:13 - Current Iteration: 10
# 2026-02-04|13:50:13 -
# 2026-02-04|13:50:13 - Target Ratio = 1.4, New Ratio = 0.02723
# 2026-02-04|13:50:13 -
# 2026-02-04|13:50:13 - Initial Pressure Drop: 186.6
# ...
