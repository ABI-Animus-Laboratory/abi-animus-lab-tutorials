# %%
# !which python
# !which pip
# Out:
# /opt/OpenCOR/bin/../Python/bin/python
# /opt/OpenCOR/bin/../Python/bin/pip

# %%
import sys
print(sys.version)
# Out:
# 3.12.2 (main, Apr  4 2024, 07:58:50) [GCC 9.4.0]

# %%
# !echo $PATH
# Out:
# /opt/OpenCOR/bin/../Python/bin:/opt/OpenCOR/bin:/opt/OpenCOR:/opt/fiji:/opt/ilastik:/opt/OpenCOR/bin:/opt/OpenCOR:/opt/fiji:/opt/ilastik:/opt/vita/bin:/opt/conda/bin:/opt/petsc-install/bin:/opt/spack/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin

# %%
# Launch ImageJ/Fiji (requires X11 forwarding)
# !/opt/fiji/fiji-linux-x64
# Out:
# Feb 05, 2026 11:09:54 AM java.util.prefs.FileSystemPreferences$1 run
# INFO: Created user preferences directory.
# Gtk-Message: 11:09:57.245: Failed to load module "canberra-gtk-module"
# [INFO] Reading available sites from https://imagej.net/

# %%
# !ilastik --help
# !ilastik --version
# !which ilastik

# # test ilastik GUI
# !ilastik
# Out:
# ...
# usage: ilastik [-h] [--version] [--headless] [--project PROJECT]
#                [--readonly [READONLY]] [--new_project NEW_PROJECT]
#                [--workflow WORKFLOW] [--clean_paths]
#                [--redirect_output REDIRECT_OUTPUT] [--debug]
#                [--logfile LOGFILE] [--process_name PROCESS_NAME]
#                [--configfile CONFIGFILE] [--fullscreen] [--exit_on_failure]
#                [--hbp] [--tiktorch_executable TIKTORCH_EXECUTABLE]
#                [--nn_device NN_DEVICE]
#
# start an ilastik workflow
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --version             show program's version number and exit
#   --headless            Don't start the ilastik gui.
#   --project PROJECT     A project file to open on startup.
#   --readonly [READONLY]
#                         Open all projects in read-only mode, to ensure you
#                         don't accidentally make changes. Per default projects
# ...

# %%
# !cd /tutorials/tutorial_5/requirements_cpp/make_and_run_scripts && bash ./run_coupler.bash
# Out:
# ./run_coupler.bash: line 15: cd: ./../generated_models/cvs_model_hybrid_cpp: No such file or directory

# %%
# build
# !cd /tutorials/tutorial_5/requirements_cpp/make_and_run_scripts && make -f MakefilePETSC clean && make -f MakefilePETSC
# Out:
# /usr/bin/rm -f ./main0d.o main0d
# mpicxx  -std=c++17 -Wall -Wextra -I/opt/petsc-install/include -Iinclude -O3 -DNDEBUG -c main0d.cpp -o main0d.o
# mpicxx  -std=c++17 -Wall -Wextra -I/opt/petsc-install/include -Iinclude -O3 -DNDEBUG -o main0d main0d.o -Wl,-rpath,/opt/petsc-install/lib -L/opt/petsc-install/lib -Wl,-rpath,/opt/petsc-install/lib -L/opt/petsc-install/lib -Wl,-rpath,/usr/lib/x86_64-linux-gnu/openmpi/lib/fortran/gfortran -L/usr/lib/x86_64-linux-gnu/openmpi/lib/fortran/gfortran -Wl,-rpath,/usr/lib/gcc/x86_64-linux-gnu/13 -L/usr/lib/gcc/x86_64-linux-gnu/13 -lpetsc -lHYPRE -ldmumps -lmumps_common -lpord -lpthread -lscalapack -lflapack -lfblas -lparmetis -lmetis -lhdf5_hl -lhdf5 -lm -lX11 -lmpi_usempif08 -lmpi_usempi_ignore_tkr -lmpi_mpifh -lmpi -lopen-rte -lopen-pal -lhwloc -levent_core -levent_pthreads -lgfortran -lm -lz -lgfortran -lm -lgfortran -lgcc_s -lquadmath -lstdc++ -lquadmath

# %%
# run the build file
# !cd /tutorials/tutorial_5/requirements_cpp/make_and_run_scripts &&./main0d
# Out:
# Hello, PETSc! Verification successful.

# %%
# !cd /tutorials/tutorial_5/requirements_cpp/make_and_run_scripts && make -f Makefile clean && make -f Makefile
# Out:
# rm -f main0d.o model0d.o main0d
# g++ -Wall -O2 -std=c++17 -I/opt/spack/opt/spack/linux-skylake/sundials-7.6.0-2ebijmnukwj5f744yuzhsnbwk6gzwap5/include -c main0d.cpp -o main0d.o
# make: *** No rule to make target 'model0d.o', needed by 'main0d'.  Stop.

# %%
# !cd /tutorials/tutorial_5/requirements_cpp/make_and_run_scripts &&./main0d
# Out:
# /usr/bin/sh: 1: ./main0d: not found
