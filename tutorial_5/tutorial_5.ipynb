# %%
# !which python
# !which pip
# Out:
# /opt/OpenCOR/bin/../Python/bin/python
# /opt/OpenCOR/bin/../Python/bin/pip

# %%
import sys
print(sys.version)
# Out:
# 3.12.2 (main, Apr  4 2024, 07:58:50) [GCC 9.4.0]

# %%
# Launch ImageJ/Fiji (requires X11 forwarding)
# !/opt/fiji/fiji-linux-x64
# Out:
# Gtk-Message: 13:07:29.507: Failed to load module "canberra-gtk-module"

# %%
# !ilastik --help
# !ilastik --version
# !which ilastik

# # test ilastik GUI
# !ilastik
# Out:
# ...
# usage: ilastik [-h] [--version] [--headless] [--project PROJECT]
#                [--readonly [READONLY]] [--new_project NEW_PROJECT]
#                [--workflow WORKFLOW] [--clean_paths]
#                [--redirect_output REDIRECT_OUTPUT] [--debug]
#                [--logfile LOGFILE] [--process_name PROCESS_NAME]
#                [--configfile CONFIGFILE] [--fullscreen] [--exit_on_failure]
#                [--hbp] [--tiktorch_executable TIKTORCH_EXECUTABLE]
#                [--nn_device NN_DEVICE]
#
# start an ilastik workflow
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --version             show program's version number and exit
#   --headless            Don't start the ilastik gui.
#   --project PROJECT     A project file to open on startup.
#   --readonly [READONLY]
#                         Open all projects in read-only mode, to ensure you
#                         don't accidentally make changes. Per default projects
# ...

# %%
# Check PETSc
# !ls -l /opt/petsc-install/lib
# !echo $PETSC_DIR
# Check Spack packages
# !spack find
# Out:
# total 258620
# drwxr-xr-x 3 root root     4096 Feb  4 17:29 cmake
# -rwxr-xr-x 1 root root 15433432 Feb  4 17:40 libHYPRE-2.31.0.so
# lrwxrwxrwx 1 root root       18 Feb  4 17:40 libHYPRE.so -> libHYPRE-2.31.0.so
# -rw-r--r-- 1 root root 12397802 Feb  4 17:36 libcmumps.a
# -rw-r--r-- 1 root root 12338178 Feb  4 17:36 libdmumps.a
# -rw-r--r-- 1 root root  1600152 Feb  4 17:24 libfblas.a
# -rw-r--r-- 1 root root 26742502 Feb  4 17:24 libflapack.a
# -rw-r--r-- 1 root root 38930838 Feb  4 17:20 libhdf5.a
# -rwxr-xr-x 1 root root      941 Feb  4 17:20 libhdf5.la
# -rw-r--r-- 1 root root     5939 Feb  4 17:20 libhdf5.settings
# lrwxrwxrwx 1 root root       18 Feb  4 17:20 libhdf5.so -> libhdf5.so.310.3.0
# lrwxrwxrwx 1 root root       18 Feb  4 17:20 libhdf5.so.310 -> libhdf5.so.310.3.0
# -rwxr-xr-x 1 root root 18632216 Feb  4 17:20 libhdf5.so.310.3.0
# -rw-r--r-- 1 root root   837204 Feb  4 17:20 libhdf5_hl.a
# -rwxr-xr-x 1 root root      996 Feb  4 17:20 libhdf5_hl.la
# ...

# %%
# build
# !cd /tutorials/tutorial_5/requirements_cpp/make_and_run_scripts && make -f MakefilePETSC
# if you see below error, you might have already build it. so delete the previous build file (./requirements_cpp/make_and_run_scripts/main0d)

# >> make: Nothing to be done for 'all'.
# Out:
# make: Nothing to be done for 'all'.

# %%
# run the build file
# !cd /tutorials/tutorial_5/requirements_cpp/make_and_run_scripts &&./main0d
# Out:
# Hello, PETSc! Verification successful.
